# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flats = pd.read_csv('train/train.tsv', sep = '\t', 
                   names = ['price', 'isNew','rooms', 'floor', 'location', 'sqrMetres'])

# %%
#flats.shape
flats.info()
#flats.columns
#flats.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1674 entries, 0 to 1673
# Data columns (total 6 columns):
# price        1674 non-null float64
# isNew        1674 non-null bool
# rooms        1674 non-null int64
# floor        1674 non-null int64
# location     1674 non-null object
# sqrMetres    1674 non-null int64
# dtypes: bool(1), float64(1), int64(3), object(1)
# memory usage: 67.1+ KB

# %%
#flats.price
#flats['price']
#flats['price'].head()
#flats.price.min()
#flats.price.quantile(0.01)
#flats = flats[flats.price > 10.0]
#flats.price.map(lambda x : x * 1000)
#flats.price = flats.price.map(lambda x : x * 1000)
#flats.price * 1000
flats.price.mean()
flats.price.max()
flats.price.sum()
# Out:
# 6.1482881967e+23

# %%
flats.plot()
plt.show()

# %%
sns.boxplot( y="price", data=flats)
plt.show()

# %%
flats_cleared = flats[flats['price'] > 5000]

# %%
sns.boxplot( y="price", data=flats_cleared)
plt.show()

# %%
sns.violinplot( y="sqrMetres", data=flats_cleared) ; plt.show()

# %%
sns.regplot( y= flats_cleared["price"], x=flats_cleared['sqrMetres']) ; plt.show()

# %%
sns.jointplot(x='sqrMetres', y="price", data=flats_cleared, kind="reg")

# %%
sns.jointplot(x='floor', y="price", data=flats_cleared, kind="reg") ; plt.show()

# %%
sns.boxplot( y="price", data=flats_cleared, x = "rooms"); plt.show()

# %%
flats['price_per_meter'] = flats.price / flats.sqrMetres
#flats.location.map(lambda x : x.split()[0])
#flats.location.map(lambda x : x.split()[0]).value_counts()
#flats.location.map(lambda x : x.split()[0]).sort_values()
#flats.sort_values('floor').floor
#flats.sort_values('floor', ascending=False)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(pd.DataFrame(flats_cleared, columns=['sqrMetres']), flats_cleared['price'])
#reg.coef_
#reg.predict(2)
#reg.predict(40)
#reg.predict(40)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#reg.predict(pd.DataFrame(flats_cleared, columns=['sqrMetres', 'floor']))
###dimensions not equal
